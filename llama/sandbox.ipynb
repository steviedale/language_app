# %%
import ollama

# %%
response = ollama.chat(model='mistral', messages=[{
    'role': 'user',
    'content': 'Give me a list of common words in Italian and their English translations.',
},])
print(response['message']['content'])
# Out:
# 1. Ciao - Hello, Goodbye
#
# 2. Grazie - Thank you
#
# 3. Prego - You're welcome
#
# 4. Scusi - Excuse me
#
# 5. Mi scuso - I'm sorry
#
# 6. Per favore - Please
#
# 7. Si - Yes
#
# 8. No - No
#
# 9. Sì, di cosa ci riferisci? - Yes, what are you referring to? (Formal)
#
# 10. No, non capisco - No, I don't understand
#
# 11. Ci vediamo - See you
#
# 12. Arrivederci - Goodbye
#
# 13. Buongiorno - Good morning
#
# 14. Buonasera - Good evening
#
# 15. Buonanotte - Good night
#
# 16. Come stai? - How are you?
#
# 17. Come ti chiami? - What is your name?
#
# 18. Dove vivo? - Where do you live?
#
# 19. Dov'è il bagno? - Where is the bathroom?
#
# 20. Cosa mangiamo oggi? - What are we having for dinner tonight?
#
# 21. Bene - Fine, Well
#
# 22. Male - Badly, Poorly
#
# 23. Molto - Very
#
# 24. Qualcosa - Something
#
# 25. Niente - Nothing
#
# 26. Un po' - A little bit
#
# 27. Molti - Many
#
# 28. Pane - Bread
#
# 29. Acqua - Water
#
# 30. Vino - Wine
#
# 31. Carne - Meat
#
# ...
